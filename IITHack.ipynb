# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight

# Load and preprocess as before
train_df = pd.read_csv("/content/sample_data/Train_Data.csv")
test_df = pd.read_csv("/content/sample_data/Test_Data.csv")
train_df = train_df.dropna(subset=["age_group"])
train_df["age_group"] = train_df["age_group"].map({"Adult": 0, "Senior": 1})

X_train = train_df.drop(columns=["SEQN", "age_group"])
y_train = train_df["age_group"]
X_test = test_df.drop(columns=["SEQN"])

imputer = SimpleImputer(strategy="median")
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

import numpy as np
weights = compute_class_weight(class_weight='balanced', classes=np.array([0, 1]), y=y_train)
class_weight_dict = {0: weights[0], 1: weights[1]}


# Build NN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2, class_weight=class_weight_dict, verbose=1)

# Predict
pred_probs = model.predict(X_test)
pred_labels = (pred_probs >= 0.5).astype(int).flatten()

# Save predictions
submission = pd.DataFrame({'age_group': pred_labels})
submission.to_csv("nn_submission.csv", index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4844 - loss: 0.7296 - val_accuracy: 0.6982 - val_loss: 0.6316
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6722 - loss: 0.6657 - val_accuracy: 0.7187 - val_loss: 0.5981
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6973 - loss: 0.6264 - val_accuracy: 0.7161 - val_loss: 0.5846
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7154 - loss: 0.5909 - val_accuracy: 0.6880 - val_loss: 0.5835
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7082 - loss: 0.6000 - val_accuracy: 0.6982 - val_loss: 0.5718
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7181 - loss: 0.5670 - val_accuracy: 0.6931 - val_loss: 0.5759
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7080 - loss: 0.5732 - val_accuracy: 0.6982 - val_loss: 0.5701
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6988 - loss: 0.5861 - val_accuracy: 0.6880 - val_loss: 0.5723
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6894 - loss: 0.5834 - val_accuracy: 0.6880 - val_loss: 0.5673
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7114 - loss: 0.5719 - val_accuracy: 0.6701 - val_loss: 0.5836
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6903 - loss: 0.5892 - val_accuracy: 0.6880 - val_loss: 0.5673
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7050 - loss: 0.5566 - val_accuracy: 0.6803 - val_loss: 0.5752
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6879 - loss: 0.5743 - val_accuracy: 0.6752 - val_loss: 0.5829
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7056 - loss: 0.5608 - val_accuracy: 0.6777 - val_loss: 0.5913
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7045 - loss: 0.5547 - val_accuracy: 0.6777 - val_loss: 0.5815
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6971 - loss: 0.5549 - val_accuracy: 0.6777 - val_loss: 0.5816
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6822 - loss: 0.5807 - val_accuracy: 0.6752 - val_loss: 0.5710
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7013 - loss: 0.5549 - val_accuracy: 0.6803 - val_loss: 0.5860
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6862 - loss: 0.5464 - val_accuracy: 0.6829 - val_loss: 0.5820
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6747 - loss: 0.5694 - val_accuracy: 0.6854 - val_loss: 0.5654
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6923 - loss: 0.5565 - val_accuracy: 0.6854 - val_loss: 0.5807
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6919 - loss: 0.5508 - val_accuracy: 0.6803 - val_loss: 0.5930
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6998 - loss: 0.5379 - val_accuracy: 0.6777 - val_loss: 0.5832
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7055 - loss: 0.5478 - val_accuracy: 0.6803 - val_loss: 0.5744
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6808 - loss: 0.5570 - val_accuracy: 0.6803 - val_loss: 0.5860
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6890 - loss: 0.5524 - val_accuracy: 0.6777 - val_loss: 0.5954
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6701 - loss: 0.5744 - val_accuracy: 0.6880 - val_loss: 0.5714
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6807 - loss: 0.5557 - val_accuracy: 0.6854 - val_loss: 0.5803
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7073 - loss: 0.5607 - val_accuracy: 0.6854 - val_loss: 0.5772
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6953 - loss: 0.5681 - val_accuracy: 0.6854 - val_loss: 0.5681
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
